# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pylab as plt
#from sklearn.cross_validation import train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("winequality-red.csv")

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
X = data[list(data.columns)[:-1]]

# %%
Y = data[['quality']]

# %%
Y
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)

# %%
train_test_split(X, Y)
# Out:
# [      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
#  500             7.8             0.520         0.25             1.9      0.081
#  460             9.2             0.430         0.52             2.3      0.083
#  896             8.3             0.310         0.39             2.4      0.078
#  1359           11.6             0.475         0.40             1.4      0.091
#  1591            5.4             0.740         0.09             1.7      0.089
#  ...             ...               ...          ...             ...        ...
#  444             5.3             0.570         0.01             1.7      0.054
#  384             7.7             0.510         0.28             2.1      0.087
#  1070            9.3             0.330         0.45             1.5      0.057
#  359            12.6             0.380         0.66             2.6      0.088
#  1592            6.3             0.510         0.13             2.3      0.076
#
# ...

# %%
regression_model  = LinearRegression()

# %%
plt.scatter(data['alcohol'], data['quality'])
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title("Alocoho Against Quality")
plt.show()

# %%
plt.scatter(data['volatile acidity'], data['quality'])
plt.xlabel('Volitile')
plt.ylabel('Quality')
plt.title("Volitty Against Quality")
plt.show()

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted = regression_model.predict(X_train)

# %%
print('R_squared', regression_model.score(X_test, y_test))
# Out:
# R_squared 0.34964597006787357

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
regressor = LinearRegression()

# %%
score = cross_val_score(regressor, X, Y, cv=5)

# %%
score
# Out:
# array([0.13200871, 0.31858135, 0.34955348, 0.369145  , 0.2809196 ])

# %%
score.mean()
# Out:
# 0.2900416288421962

# %%
from sklearn import datasets

# %%
datasets.load_diabetes()
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990842, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06832974, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286377, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04687948,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452837, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00421986,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
y_test = y_test.reset_index(drop=True)
predictions = cross_val_predict(regressor, X_test, y_test)

# %%
y_test
# Out:
#      quality
# 0          5
# 1          5
# 2          6
# 3          6
# 4          6
# ..       ...
# 395        7
# 396        6
# 397        6
# 398        5
# 399        5
#
# [400 rows x 1 columns]

# %%
y_test = y_test.quality

# %%
y_test = y_test

# %%
for i, p in enumerate(predictions):
    print(f"Actual {y_test[i]} and prediction is {p}")
# Out:
# Actual 5 and prediction is [5.16744634]
# Actual 5 and prediction is [5.11853637]
# Actual 6 and prediction is [4.99478624]
# Actual 6 and prediction is [5.96555571]
# Actual 6 and prediction is [4.9620855]
# Actual 5 and prediction is [5.29018188]
# Actual 5 and prediction is [5.44021034]
# Actual 6 and prediction is [6.14800402]
# Actual 5 and prediction is [5.24021467]
# Actual 5 and prediction is [5.27412496]
# Actual 6 and prediction is [6.00454281]
# Actual 6 and prediction is [5.72080105]
# Actual 5 and prediction is [5.14229757]
# Actual 5 and prediction is [5.68450441]
# Actual 4 and prediction is [4.87390875]
# Actual 6 and prediction is [5.26802516]
# Actual 6 and prediction is [6.00981096]
# Actual 5 and prediction is [5.00049966]
# Actual 5 and prediction is [5.04072781]
# Actual 5 and prediction is [5.19284278]
# Actual 6 and prediction is [5.94356294]
# Actual 6 and prediction is [5.73533607]
# Actual 5 and prediction is [5.49940052]
# ...

# %%
# Out:
# 1599

# %%
plt.scatter( y_test, predictions)
plt.ylabel('Prediction')
plt.xlabel('Quality')
plt.title("predicted Against Quality")
plt.show()
